# %% [markdown]
# # 1. 環境設定 (Windows 版本)

# %%
import sys
print(f"Python 版本: {sys.version}")
# !{sys.executable} -m pip install -U numpy==1.26.4

# %%
import sys
# !{sys.executable} -m pip install -U ray==2.6.0
import ray
print(f"Ray 版本: {ray.__version__}")

# %%
import torch
print(f"PyTorch 版本: {torch.__version__}")
print(f"CUDA 可用: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA 版本: {torch.version.cuda}")
    print(f"GPU 裝置: {torch.cuda.get_device_name(0)}")

# %%
import sys
# !{sys.executable} -m pip install -U monai==1.2.0
import monai
print(f"MONAI 版本: {monai.__version__}")

# %%
# !pip install -U ml_collections
# !pip install timm
# !pip install einops
# !pip install scipy
# !pip install nibabel

# %%
# !git clone https://github.com/kairaun/Sam.git

# %%
# 安裝 Sam
# %cd Sam
# !dir
# !type pyproject.toml
# !pip install -e .
# %cd ..

# %%
import sys
# !{sys.executable} -m pip install -U --no-deps monailabel
import monailabel
print(f"MONAILabel 版本: {monailabel.__version__}")

# %%
# !pip install "pydantic<2.0"

# %%
# !git clone https://github.com/kairaun/CardiacSegV2.git

# %%
# 安裝環境 (Windows 版本)
# !pip install gdown==4.6.0

# 注意：不直接安裝 requirements.txt，因為它包含舊版本的 PyTorch
# 我們會手動安裝需要的套件
print("正在安裝其他必要套件...")

# 讀取 requirements.txt 並過濾掉 PyTorch 相關套件
import os
req_file = os.path.join('CardiacSegV2', 'requirements.txt')
if os.path.exists(req_file):
    with open(req_file, 'r') as f:
        packages = [line.strip() for line in f if line.strip() and not line.startswith('#')]
    
    # 過濾掉已安裝或不相容的套件
    skip_packages = ['torch', 'torchvision', 'torchaudio', 'monai', 'monailabel']
    packages_to_install = [p for p in packages if not any(skip in p.lower() for skip in skip_packages)]
    
    print(f"將安裝以下套件: {packages_to_install}")
    for pkg in packages_to_install:
        try:
            print(f"安裝 {pkg}...")
            get_ipython().system(f'pip install {pkg}')
        except Exception as e:
            print(f"警告: {pkg} 安裝失敗 - {e}")
else:
    print("找不到 requirements.txt，跳過套件安裝")

# %%
# 修改程式碼以適應 Windows 路徑
import os

# 取得當前工作目錄
workspace_dir = os.path.abspath('CardiacSegV2')
print(f"工作目錄: {workspace_dir}")

# 讀取並修改 setup_dir.py
setup_dir_path = os.path.join(workspace_dir, 'setup_dir.py')
with open(setup_dir_path, 'r', encoding='utf-8') as f:
    content = f.read()

# 替換路徑 (使用 os.path.join 以支援 Windows)
content = content.replace('/content/CardiacSegV2/', workspace_dir.replace('\\', '/') + '/')

with open(setup_dir_path, 'w', encoding='utf-8') as f:
    f.write(content)

print("setup_dir.py 已更新")

# %%
# 修改 infer.py 和 tune.py
import os

workspace_dir = os.path.abspath('CardiacSegV2')

# 修改 infer.py
infer_path = os.path.join(workspace_dir, 'expers', 'infer.py')
if os.path.exists(infer_path):
    with open(infer_path, 'r', encoding='utf-8') as f:
        content = f.read()
    content = content.replace('sys.path.append("/content/CardiacSegV2")', 
                             f'sys.path.append("{workspace_dir.replace(chr(92), chr(92)+chr(92))}")')
    with open(infer_path, 'w', encoding='utf-8') as f:
        f.write(content)
    print("infer.py 已更新")

# 修改 tune.py
tune_path = os.path.join(workspace_dir, 'expers', 'tune.py')
if os.path.exists(tune_path):
    with open(tune_path, 'r', encoding='utf-8') as f:
        content = f.read()
    content = content.replace('sys.path.append("/content/CardiacSegV2")', 
                             f'sys.path.append("{workspace_dir.replace(chr(92), chr(92)+chr(92))}")')
    content = content.replace('ray.init(runtime_env={"working_dir": "/content/CardiacSegV2"})',
                             f'ray.init(runtime_env={{"working_dir": "{workspace_dir.replace(chr(92), chr(92)+chr(92))}"}})') 
    with open(tune_path, 'w', encoding='utf-8') as f:
        f.write(content)
    print("tune.py 已更新")

# %%
# !python CardiacSegV2\setup_dir.py

# %% [markdown]
# # 2. 設定訓練參數

# %%
import os

# 使用 Windows 風格的路徑
workspace_dir = os.path.abspath('CardiacSegV2')
model_name = 'attention_unet'
data_name = 'chgh'
exp_name = 'AICUP_training'
data_dict_file_name = 'AICUP_training.json'

# 設定實驗目錄
root_exp_dir = os.path.join(workspace_dir, 'exps', 'exps', model_name, data_name, 'tune_results')

# 設定資料目錄
root_data_dir = os.path.join(workspace_dir, 'dataset', data_name)
data_dir = root_data_dir

# data dict json 路徑
data_dicts_json = os.path.join(workspace_dir, 'exps', 'data_dicts', data_name, data_dict_file_name)

# 設定模型、日誌、評估目錄
model_dir = os.path.join('.', 'models')
log_dir = os.path.join('.', 'logs')
eval_dir = os.path.join('.', 'evals')

os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

# 模型路徑
best_checkpoint = os.path.join(model_dir, 'best_model.pth')
final_checkpoint = os.path.join(model_dir, 'final_model.pth')

# 建立根實驗目錄
os.makedirs(root_exp_dir, exist_ok=True)

print(f"工作目錄: {workspace_dir}")
print(f"實驗目錄: {root_exp_dir}")
print(f"資料目錄: {data_dir}")
print(f"模型目錄: {model_dir}")
# Out:
# 工作目錄: d:\Felix\ML\Code\CardiacSegV2
# 實驗目錄: d:\Felix\ML\Code\CardiacSegV2\exps\exps\attention_unet\chgh\tune_results
# 資料目錄: d:\Felix\ML\Code\CardiacSegV2\dataset\chgh
# 模型目錄: .\models

# %% [markdown]
# # 3. 正式訓練
#
# 執行模型訓練，訓練參數可以根據需要調整。

# %% [markdown]
# cd D:\Felix\ML\Code\CardiacSegV2
#
# python expers/tune.py --tune_mode=train --exp_name=AICUP_training --data_name=chgh --data_dir=D:\Felix\ML\Code\CardiacSegV2\dataset\chgh --root_exp_dir=D:\Felix\ML\Code\CardiacSegV2\exps\exps\unet3d\chgh\tune_results --model_name=unet3d --model_dir=.\models --log_dir=.\logs --eval_dir=.\evals --start_epoch=0 --val_every=5 --max_early_stop_count=2 --max_epoch=20 --data_dicts_json=D:\Felix\ML\Code\CardiacSegV2\exps\data_dicts\chgh\AICUP_training.json --pin_memory --out_channels=4 --patch_size=4 --feature_size=48 --drop_rate=0.1 --depths 3 3 9 3 --kernel_size 7 --exp_rate 4 --norm_name=layer --a_min=-42 --a_max=423 --space_x=0.7 --space_y=0.7 --space_z=1.0 --roi_x=128 --roi_y=128 --roi_z=120 --optim=AdamW --lr=5e-4 --weight_decay=5e-4 --checkpoint=.\models\final_model.pth --use_init_weights --infer_post_process

# %%
# 訓練模型 (Windows 版本)
import os
import sys
import subprocess

# 確保在正確的目錄
original_dir = os.getcwd()
os.chdir(workspace_dir)

print(f"當前工作目錄: {os.getcwd()}")
print("開始訓練...\n")

# 建構訓練命令
train_cmd = [
    sys.executable, "expers/tune.py",
    "--tune_mode=train",
    f"--exp_name={exp_name}",
    f"--data_name={data_name}",
    f"--data_dir={data_dir}",
    f"--root_exp_dir={root_exp_dir}",
    f"--model_name={model_name}",
    f"--model_dir={model_dir}",
    f"--log_dir={log_dir}",
    f"--eval_dir={eval_dir}",
    "--start_epoch=0",
    "--val_every=5",
    "--max_early_stop_count=2",
    "--max_epoch=20",
    f"--data_dicts_json={data_dicts_json}",
    "--pin_memory",
    "--out_channels=4",
    "--patch_size=4",
    "--feature_size=48",
    "--drop_rate=0.1",
    "--depths", "3", "3", "9", "3",
    "--kernel_size", "7",
    "--exp_rate", "4",
    "--norm_name=layer",
    "--a_min=-42",
    "--a_max=423",
    "--space_x=0.7",
    "--space_y=0.7",
    "--space_z=1.0",
    "--roi_x=128",
    "--roi_y=128",
    "--roi_z=120",
    "--optim=AdamW",
    "--lr=5e-4",
    "--weight_decay=5e-4",
    f"--checkpoint={final_checkpoint}",
    "--use_init_weights",
    "--infer_post_process"
]

print("執行命令:")
print(" ".join(train_cmd))
print("\n" + "="*80 + "\n")

# 使用 Popen 來即時顯示輸出
process = subprocess.Popen(
    train_cmd,
    cwd=workspace_dir,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    universal_newlines=True
)

# 即時打印輸出
for line in process.stdout:
    print(line, end='')

# 等待程序完成
return_code = process.wait()

# 切回原始目錄
os.chdir(original_dir)

print("\n" + "="*80)
if return_code == 0:
    print("\n✅ 訓練完成！")
    print(f"最佳模型已儲存至: {best_checkpoint}")
    print(f"最終模型已儲存至: {final_checkpoint}")
else:
    print(f"\n❌ 訓練失敗，錯誤碼: {return_code}")
    print("請查看上方的錯誤訊息以了解失敗原因")
# Out:
# 當前工作目錄: d:\Felix\ML\Code\CardiacSegV2
# 開始訓練...
#
# 執行命令:
# d:\Felix\ML\Code\.conda\python.exe expers/tune.py --tune_mode=train --exp_name=AICUP_training --data_name=chgh --data_dir=d:\Felix\ML\Code\CardiacSegV2\dataset\chgh --root_exp_dir=d:\Felix\ML\Code\CardiacSegV2\exps\exps\attention_unet\chgh\tune_results --model_name=attention_unet --model_dir=.\models --log_dir=.\logs --eval_dir=.\evals --start_epoch=0 --val_every=5 --max_early_stop_count=2 --max_epoch=20 --data_dicts_json=d:\Felix\ML\Code\CardiacSegV2\exps\data_dicts\chgh\AICUP_training.json --pin_memory --out_channels=4 --patch_size=4 --feature_size=48 --drop_rate=0.1 --depths 3 3 9 3 --kernel_size 7 --exp_rate 4 --norm_name=layer --a_min=-42 --a_max=423 --space_x=0.7 --space_y=0.7 --space_z=1.0 --roi_x=128 --roi_y=128 --roi_z=120 --optim=AdamW --lr=5e-4 --weight_decay=5e-4 --checkpoint=.\models\final_model.pth --use_init_weights --infer_post_process
#
# ================================================================================
#
# Importing from timm.models.layers is deprecated, please import via timm.layers
# Importing from timm.models.registry is deprecated, please import via timm.models
# Setting a `RunConfig.local_dir` is deprecated and will be removed in the future. If you are not using remote storage,set the `RunConfig.storage_path` instead. Otherwise, set the`RAY_AIR_LOCAL_CACHE_DIR` environment variable to control the local cache location.
# Importing from timm.models.layers is deprecated, please import via timm.layers
# Importing from timm.models.registry is deprecated, please import via timm.models
# Setting a `RunConfig.local_dir` is deprecated and will be removed in the future. If you are not using remote storage,set the `RunConfig.storage_path` instead. Otherwise, set the`RAY_AIR_LOCAL_CACHE_DIR` environment variable to control the local cache location.
# 2025-10-16 18:00:47,788	INFO worker.py:1621 -- Started a local Ray instance.
# 2025-10-16 18:00:49,304	INFO tune.py:226 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# 2025-10-16 18:00:49,326	INFO tune.py:666 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2025-10-16 18:00:49,332	INFO tensorboardx.py:178 -- pip install "ray[tune]" to see TensorBoard files.
# 2025-10-16 18:00:49,332	WARNING callback.py:144 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# 2025-10-16 18:00:49,333	WARNING tune.py:997 -- AIR_VERBOSITY is set, ignoring passed-in ProgressReporter for now.
# ╭────────────────────────────────────────────────────────╮
# │ Configuration for experiment     AICUP_training        │
# ├────────────────────────────────────────────────────────┤
# │ Search algorithm                 BasicVariantGenerator │
# │ Scheduler                        FIFOScheduler         │
# │ Number of trials                 1                     │
# ╰────────────────────────────────────────────────────────╯
#
# View detailed results here: d://\Felix\ML\Code\CardiacSegV2\exps\exps\attention_unet\chgh\tune_results\AICUP_training
#
# Trial status: 1 PENDING
# Current time: 2025-10-16 18:00:49. Total running time: 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   PENDING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# (pid=23396) Importing from timm.models.layers is deprecated, please import via timm.layers
# (pid=23396) Importing from timm.models.registry is deprecated, please import via timm.models
# Training started with configuration:
# ╭────────────────────────────────────╮
# │ Training config                    │
# ├────────────────────────────────────┤
# │ exp/exp             AICUP_training │
# ╰────────────────────────────────────╯
#
# (func pid=23396) a_max 423.0
# (func pid=23396) a_min -42.0
# (func pid=23396) space_x 0.7
# (func pid=23396) roi_x 128
# (func pid=23396) lr 0.0005
# (func pid=23396) weight_decay 0.0005
# (func pid=23396) warmup_epochs 50
# (func pid=23396) max_epochs 20
# (func pid=23396) cuda is available
# (func pid=23396) model: attention_unet
# (func pid=23396) monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# (func pid=23396) <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# (func pid=23396) monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# (func pid=23396) loss: dice ce loss
# (func pid=23396) optimzer: AdamW
# (func pid=23396) {'lr': 0.0005, 'weight_decay': 0.0005}
# (func pid=23396) load json from d:\Felix\ML\Code\CardiacSegV2\exps\data_dicts\chgh\AICUP_training.json
# (func pid=23396) train files (9): ['patient0011', 'patient0012', 'patient0013', 'patient0014', 'patient0015', 'patient0016', 'patient0017', 'patient0018', 'patient0019']
# (func pid=23396) val files (3): ['patient0048', 'patient0049', 'patient0050']
# (func pid=23396) test files (3): ['patient0001', 'patient0002', 'patient0003']
# (func pid=23396)
# (func pid=23396) load train dataset ...
# (func pid=23396) Using MONAI Cache Dataset
# (func pid=23396)
# Loading dataset:   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23396)
# Loading dataset:  11%|█         | 1/9 [00:05<00:45,  5.67s/it]
# (func pid=23396)
# Loading dataset:  22%|██▏       | 2/9 [00:07<00:24,  3.52s/it]
# (func pid=23396)
# Loading dataset:  33%|███▎      | 3/9 [00:11<00:22,  3.68s/it]
# (func pid=23396)
# Loading dataset:  44%|████▍     | 4/9 [00:12<00:12,  2.59s/it]
# (func pid=23396)
# Loading dataset:  56%|█████▌    | 5/9 [00:16<00:12,  3.19s/it]
# (func pid=23396)
# Loading dataset:  67%|██████▋   | 6/9 [00:19<00:09,  3.12s/it]
# (func pid=23396)
# Loading dataset:  78%|███████▊  | 7/9 [00:23<00:06,  3.36s/it]
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18
 30s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:07:50. Total running time: 7min 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:08:20. Total running time: 7min 30s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:08:50. Total running time: 8min 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# (func pid=23396)
# Validate (54 / 10 Steps):   0%|          | 0/3 [05:30<?, ?it/s]
# Validate (54 / 10 Steps):  33%|███▎      | 1/3 [05:30<11:00, 330.21s/it]
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:09:20. Total running time: 8min 30s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:09:50. Total running time: 9min 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:10:20. Total running time: 9min 30s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:10:50. Total running time: 10min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# 2025-10-16 18:10:52,125	WARNING syncer.py:585 -- Last sync command failed: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training', which is outside base dir 'C:\Users\User\ray_results\AICUP_training'
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:11:20. Total running time: 10min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:11:50. Total running time: 11min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:12:20. Total running time: 11min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:12:50. Total running time: 12min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:13:20. Total running time: 12min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:13:50. Total running time: 13min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:14:20. Total running time: 13min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# (func pid=23396)
# Validate (54 / 10 Steps):  33%|███▎      | 1/3 [11:01<11:00, 330.21s/it]
# Validate (54 / 10 Steps):  67%|██████▋   | 2/3 [11:01<05:31, 331.03s/it]
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:14:50. Total running time: 14min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:15:20. Total running time: 14min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:15:50. Total running time: 15min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# 2025-10-16 18:15:53,412	WARNING syncer.py:585 -- Last sync command failed: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training', which is outside base dir 'C:\Users\User\ray_results\AICUP_training'
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:16:20. Total running time: 15min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:16:50. Total running time: 16min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:17:20. Total running time: 16min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:17:50. Total running time: 17min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:18:20. Total running time: 17min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:18:50. Total running time: 18min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:19:20. Total running time: 18min 31s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 18:19:50. Total running time: 19min 1s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# (func pid=23396)
# Validate (54 / 10 Steps):  67%|██████▋   | 2/3 [16:35<05:31, 331.03s/it]
# Validate (54 / 10 Steps): 100%|██████████| 3/3 [16:35<00:00, 332.25s/it]
# (func pid=23396)
# Validate (54 / 10 Steps): 100%|██████████| 3/3 [16:36<00:00, 332.13s/it]
# (func pid=23396) Saving checkpoint .\models\best_model.pth
# (func pid=23396) Best Model Was Saved ! Current Best Avg. Dice: 0.34176793694496155 Current Avg. Dice: 0.34176793694496155
# Training finished iteration 1 at 2025-10-16 18:19:58. Total running time: 19min 8s
# ╭──────────────────────────────╮
# │ Training result              │
# ├──────────────────────────────┤
# │ time_this_iter_s     1142.89 │
# │ time_total_s         1142.89 │
# │ training_iteration         1 │
# │ esc                        0 │
# │ tt_dice                    0 │
# │ tt_iou                     0 │
# │ val_bst_acc          0.34177 │
# ╰──────────────────────────────╯
#
# (func pid=23396)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23396) Saving checkpoint .\models\final_model.pth
# (func pid=23396) Final Model Was Saved ! Current Best Avg. Dice: 0.34176793694496155 Current Avg. Dice: 0.34176793694496155
# (func pid=23396)
# [Epoch 6] Training (54 Steps) (loss=1.62714):   0%|          | 0/9 [00:09<?, ?it/s]
# [Epoch 6] Training (54 Steps) (loss=1.62714):  11%|█         | 1/9 [00:09<01:16,  9.51s/it]
# (func pid=23396)
# [Epoch 6] Training (55 Steps) (loss=1.48453):  11%|█         | 1/9 [00:10<01:16,  9.51s/it]
# [Epoch 6] Training (55 Steps) (loss=1.48453):  22%|██▏       | 2/9 [00:10<00:30,  4.36s/it]
# (func pid=23396)
# [Epoch 6] Training (56 Steps) (loss=1.43619):  22%|██▏       | 2/9 [00:10<00:30,  4.36s/it]
# [Epoch 6] Training (56 Steps) (loss=1.43619):  33%|███▎      | 3/9 [00:10<00:16,  2.70s/it]
# (func pid=23396)
# [Epoch 7] Training (68 Steps) (loss=1.40006):  67%|██████▋   | 6/9 [00:12<00:03,  1.10s/it]
# (func pid=23396)
# [Epoch 7] Training (69 Steps) (loss=1.44249):  67%|██████▋   | 6/9 [00:13<00:03,  1.10s/it]
# [Epoch 7] Training (69 Steps) (loss=1.44249):  78%|███████▊  | 7/9 [00:13<00:01,  1.09it/s]
# (func pid=23396)
# [Epoch 7] Training (70 Steps) (loss=1.33233):  78%|███████▊  | 7/9 [00:13<00:01,  1.09it/s]
# [Epoch 7] Training (70 Steps) (loss=1.33233):  89%|████████▉ | 8/9 [00:13<00:00,  1.26it/s]
# (func pid=23396)
# [Epoch 7] Training (71 Steps) (loss=1.39480):  89%|████████▉ | 8/9 [00:14<00:00,  1.26it/s]
# [Epoch 7] Training (71 Steps) (loss=1.39480): 100%|██████████| 9/9 [00:14<00:00,  1.40it/s]
# (func pid=23396)
# [Epoch 7] Training (71 Steps) (loss=1.39480): 100%|██████████| 9/9 [00:15<00:00,  1.67s/it]
# (func pid=23396)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23396)
# [Epoch 8] Training (72 Steps) (loss=1.44827):   0%|          | 0/9 [00:09<?, ?it/s]
# [Epoch 8] Training (72 Steps) (loss=1.44827):  11%|█         | 1/9 [00:09<01:15,  9.45s/it]
# (func pid=23396)
# [Epoch 8] Training (73 Steps) (loss=1.36293):  11%|█         | 1/9 [00:10<01:15,  9.45s/it]
# [Epoch 8] Training (73 Steps) (loss=1.36293):  22%|██▏       | 2/9 [00:10<00:30,  4.29s/it]
# (func pid=23396)
# [Epoch 8] Training (74 Steps) (loss=1.56134):  22%|██▏       | 2/9 [00:10<00:30,  4.29s/it]
# [Epoch 8] Training (74 Steps) (loss=1.56134):  33%|███▎      | 3/9 [00:10<00:15,  2.62s/it]
# (func pid=23396)
# [Epoch 8] Training (75 Steps) (loss=1.41269):  33%|███▎      | 3/9 [00:11<00:15,  2.62s/it]
# [Epoch 8] Training (75 Steps) (loss=1.41269):  44%|████▍     | 4/9 [00:11<00:09,  1.82s/it]
# (func pid=23396)
# [Epoch 8] Training (76 Steps) (loss=1.66951):  44%|████▍     | 4/9 [00:11<00:09,  1.82s/it]
# [Epoch 8] Training (76 Steps) (loss=1.66951):  56%|█████▌    | 5/9 [00:11<00:05,  1.37s/it]
# (func pid=23396)
# [Epoch 8] Training (77 Steps) (loss=1.39151):  56%|█████▌    | 5/9 [00:12<00:05,  1.37s/it]
# [Epoch 8] Training (77 Steps) (loss=1.39151):  67%|██████▋   | 6/9 [00:12<00:03,  1.09s/it]
# (func pid=23396)
# [Epoch 8] Training (78 Steps) (loss=1.30916):  67%|██████▋   | 6/9 [00:12<00:03,  1.09s/it]
# [Epoch 8] Training (78 Steps) (loss=1.30916):  78%|███████▊  | 7/9 [00:12<00:01,  1.10it/s]
# (func pid=23396)
# [Epoch 8] Training (79 Steps) (loss=1.36842):  78%|███████▊  | 7/9 [00:13<00:01,  1.10it/s]
# [Epoch 8] Training (79 Steps) (loss=1.36842):  89%|████████▉ | 8/9 [00:13<00:00,  1.27it/s]
# (func pid=23396)
# [Epoch 8] Training (80 Steps) (loss=1.55716):  89%|████████▉ | 8/9 [00:14<00:00,  1.27it/s]
# [Epoch 8] Training (80 Steps) (loss=1.55716): 100%|██████████| 9/9 [00:14<00:00,  1.41it/s]
# (func pid=23396)
# [Epoch 8] Training (80 Steps) (loss=1.55716): 100%|██████████| 9/9 [00:14<00:00,  1.66s/it]
# (func pid=23396)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# Trial status: 1 RUNNING
# Current time: 2025-10-16
   0%|          | 0/9 [00:09<?, ?it/s]
# [Epoch 10] Training (90 Steps) (loss=1.30459):  11%|█         | 1/9 [00:09<01:16,  9.51s/it]
# (func pid=23396)
# [Epoch 10] Training (91 Steps) (loss=1.32227):  11%|█         | 1/9 [00:10<01:16,  9.51s/it]
# [Epoch 10] Training (91 Steps) (loss=1.32227):  22%|██▏       | 2/9 [00:10<00:30,  4.32s/it]
# (func pid=23396)
# [Epoch 10] Training (92 Steps) (loss=1.48595):  22%|██▏       | 2/9 [00:10<00:30,  4.32s/it]
# [Epoch 10] Training (92 Steps) (loss=1.48595):  33%|███▎      | 3/9 [00:10<00:15,  2.64s/it]
# (func pid=23396)
# [Epoch 10] Training (93 Steps) (loss=1.35317):  33%|███▎      | 3/9 [00:11<00:15,  2.64s/it]
# [Epoch 10] Training (93 Steps) (loss=1.35317):  44%|████▍     | 4/9 [00:11<00:09,  1.84s/it]
# (func pid=23396)
# [Epoch 10] Training (94 Steps) (loss=1.21884):  44%|████▍     | 4/9 [00:12<00:09,  1.84s/it]
# ...
#
# (func pid=23396) invalid value encountered in divide
# (func pid=23396) Confusion_Vals： [[5.0169500e+05 2.0167600e+05 1.4801850e+07 7.3104000e+04]
# (func pid=23396)  [0.0000000e+00 1.0000000e+00 1.5567918e+07 1.0406000e+04]
# (func pid=23396)  [0.0000000e+00 1.0000000e+00 1.5578324e+07 0.0000000e+00]]
# (func pid=23396) infer test time aug:
# (func pid=23396) dice: [0.78502077 0.                nan]
# (func pid=23396) iou: [0.6461187 0.              nan]
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:28:27. Total running time: 1hr 27min 37s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# (func pid=23396) Confusion_Vals： [[3.37063300e+06 1.25079200e+06 9.74130960e+07 4.63781000e+05]
# (func pid=23396)  [0.00000000e+00 0.00000000e+00 1.02430048e+08 6.82560000e+04]
# (func pid=23396)  [0.00000000e+00 8.00000000e+00 1.02498296e+08 0.00000000e+00]]
# (func pid=23396) infer test original:
# (func pid=23396) dice: [0.7972316 0.              nan]
# (func pid=23396) iou: [0.66283053 0.                nan]
# (func pid=23396) sensitivity: [0.87904775 0.                nan]
# (func pid=23396) specificity: [0.9873227  1.         0.99999994]
# (func pid=23396) infer data: {'image': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0003.nii.gz', 'label': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0003_gt.nii.gz'}
# (func pid=23396) infer time: 0.3523881435394287 sec
# (func pid=23396) use post process infer
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:28:57. Total running time: 1hr 28min 7s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:29:27. Total running time: 1hr 28min 37s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:29:57. Total running time: 1hr 29min 8s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:30:27. Total running time: 1hr 29min 38s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:30:57. Total running time: 1hr 30min 8s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# 2025-10-16 19:31:10,938	WARNING syncer.py:585 -- Last sync command failed: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training', which is outside base dir 'C:\Users\User\ray_results\AICUP_training'
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:31:27. Total running time: 1hr 30min 38s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:31:57. Total running time: 1hr 31min 8s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:32:27. Total running time: 1hr 31min 38s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:32:57. Total running time: 1hr 32min 8s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 19:33:28. Total running time: 1hr 32min 38s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   RUNNING    ...'AICUP_training'}        4            4472.38           0          0        0.531965       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# (func pid=23396) Confusion_Vals： [[5.0186500e+05 1.5989800e+05 1.5709236e+07 1.1428300e+05]
# (func pid=23396)  [0.0000000e+00 2.0000000e+00 1.6472527e+07 1.2753000e+04]
# (func pid=23396)  [0.0000000e+00 6.0000000e+00 1.6485276e+07 0.0000000e+00]]
# (func pid=23396) infer test time aug:
# (func pid=23396) dice: [0.7854459 0.              nan]
# (func pid=23396) iou: [0.6466949 0.              nan]
# (func pid=23396) Confusion_Vals： [[2.607382e+06 8.020480e+05 8.093566e+07 5.895640e+05]
# (func pid=23396)  [0.000000e+00 1.600000e+01 8.486848e+07 6.616100e+04]
# (func pid=23396)  [0.000000e+00 3.200000e+01 8.493462e+07 0.000000e+00]]
# (func pid=23396) infer test original:
# (func pid=23396) dice: [0.78935295 0.                nan]
# (func pid=23396) iou: [0.6520091 0.              nan]
# (func pid=23396) sensitivity: [0.81558526 0.                nan]
# (func pid=23396) specificity: [0.9901875  0.9999998  0.99999964]
# (func pid=23396)
# (func pid=23396) eval result:
# (func pid=23396) avg tt dice: 0.3489282
# (func pid=23396) avg tt iou: 0.28720468
# (func pid=23396) avg inf dice: 0.35276368
# (func pid=23396) avg inf iou: 0.29244506
# (func pid=23396) avg inf sensitivity: 0.37744895
# (func pid=23396) avg inf specificity: 0.99625367
# (func pid=23396) avg inf time: 0.32727917035420734
# Training finished iteration 5 at 2025-10-16 19:33:42. Total running time: 1hr 32min 53s
# ╭───────────────────────────────╮
# │ Training result               │
# ├───────────────────────────────┤
# │ time_this_iter_s      1095.08 │
# │ time_total_s          5567.46 │
# │ training_iteration          5 │
# │ inf_dice             0.352764 │
# │ inf_iou              0.292445 │
# │ inf_time              0.32728 │
# │ tt_dice              0.348928 │
# │ tt_iou               0.287205 │
# │ val_bst_acc           0.53197 │
# ╰───────────────────────────────╯
#
# Training completed after 5 iterations at 2025-10-16 19:33:42. Total running time: 1hr 32min 53s
#
# 2025-10-16 19:33:42,773	WARNING tune.py:1122 -- Trial Runner checkpointing failed: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training', which is outside base dir 'C:\Users\User\ray_results\AICUP_training'
# Trial status: 1 TERMINATED
# Current time: 2025-10-16 19:33:42. Total running time: 1hr 32min 53s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status       exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_fe088_00000   TERMINATED   ...'AICUP_training'}        5            5567.46    0.348928   0.287205        0.531965 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# (func pid=23396) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_fe088_00000_0_exp=exp_AICUP_training_2025-10-16_18-00-49', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_fe088_00000_0_exp=exp_AICUP_training_2025-10-16_18-00-49\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23396)      patientId  tt_diceC  tt_diceAO  tt_diceCA   tt_iouC  tt_iouAO  tt_iouCA  inf_diceC  inf_diceAO  inf_diceCA  inf_iouC  inf_iouAO  inf_iouCA  inf_sensitivityC  inf_sensitivityAO  inf_sensitivityCA  inf_specificityC  inf_specificityAO  inf_specificityCA  inf_time
# (func pid=23396) 0  patient0001  0.784654        0.0        0.0  0.645622       0.0       0.0   0.794996         0.0         0.0  0.659746        0.0        0.0          0.855091                0.0                0.0          0.988773                1.0                1.0  0.302541
# (func pid=23396) 1  patient0002  0.785021        0.0        NaN  0.646119       0.0       NaN   0.797232         0.0         NaN  0.662831        0.0        NaN          0.879048                0.0                NaN          0.987323                1.0                1.0  0.326908
# (func pid=23396) 2  patient0003  0.785446        0.0        NaN  0.646695       0.0       NaN   0.789353         0.0         NaN  0.652009        0.0        NaN          0.815585                0.0                NaN          0.990188                1.0                1.0  0.352388
# (func pid=23396) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_fe088_00000_0_exp=exp_AICUP_training_2025-10-16_18-00-49', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_fe088_00000_0_exp=exp_AICUP_training_2025-10-16_18-00-49\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23396) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_fe088_00000_0_exp=exp_AICUP_training_2025-10-16_18-00-49', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_fe088_00000_0_exp=exp_AICUP_training_2025-10-16_18-00-49\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23396) Could not upload checkpoint to d://\Felix\ML\Code\CardiacSegV2\exps\exps\attention_unet\chgh\tune_results\AICUP_training\main_fe088_00000_0_exp=exp_AICUP_training_2025-10-16_18-00-49 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
#
# ================================================================================
#
# ✅ 訓練完成！
# 最佳模型已儲存至: .\models\best_model.pth
# 最終模型已儲存至: .\models\final_model.pth

# %% [markdown]
# # 4. 測試訓練結果
#
# 使用訓練好的模型進行測試評估。

# %%
# 測試模型 (Windows 版本)
import os
import sys
import subprocess

# 確保在正確的目錄
original_dir = os.getcwd()
os.chdir(workspace_dir)

print(f"當前工作目錄: {os.getcwd()}")
print("開始測試...\n")

# 建構測試命令
test_cmd = [
    sys.executable, "expers/tune.py",
    "--tune_mode=test",
    f"--exp_name={exp_name}",
    f"--data_name={data_name}",
    f"--data_dir={data_dir}",
    f"--root_exp_dir={root_exp_dir}",
    f"--model_name={model_name}",
    f"--model_dir={model_dir}",
    f"--log_dir={log_dir}",
    f"--eval_dir={eval_dir}",
    f"--data_dicts_json={data_dicts_json}",
    "--pin_memory",
    "--out_channels=4",
    "--patch_size=4",
    "--feature_size=48",
    "--drop_rate=0.1",
    "--depths", "3", "3", "9", "3",
    "--kernel_size", "7",
    "--exp_rate", "4",
    "--norm_name=layer",
    "--a_min=-42",
    "--a_max=423",
    "--space_x=0.7",
    "--space_y=0.7",
    "--space_z=1.0",
    "--roi_x=128",
    "--roi_y=128",
    "--roi_z=128",
    "--optim=AdamW",
    "--lr=5e-4",
    "--weight_decay=5e-4",
    f"--checkpoint={final_checkpoint}",
    "--use_init_weights",
    "--infer_post_process",
    "--resume_tuner",
    "--save_eval_csv",
    "--test_mode"
]

print("執行命令:")
print(" ".join(test_cmd))
print("\n" + "="*80 + "\n")

# 使用 Popen 來即時顯示輸出
process = subprocess.Popen(
    test_cmd,
    cwd=workspace_dir,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    universal_newlines=True
)

# 即時打印輸出
for line in process.stdout:
    print(line, end='')

# 等待程序完成
return_code = process.wait()

# 切回原始目錄
os.chdir(original_dir)

print("\n" + "="*80)
if return_code == 0:
    print("\n✅ 測試完成！")
else:
    print(f"\n❌ 測試失敗，錯誤碼: {return_code}")
    print("請查看上方的錯誤訊息以了解失敗原因")
