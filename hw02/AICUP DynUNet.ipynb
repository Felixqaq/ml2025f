# %% [markdown]
# # 1. 環境設定 (Windows 版本)

# %%
import sys
print(f"Python 版本: {sys.version}")
# !{sys.executable} -m pip install -U numpy==1.26.4

# %%
import sys
# !{sys.executable} -m pip install -U ray==2.6.0
import ray
print(f"Ray 版本: {ray.__version__}")

# %%
import torch
print(f"PyTorch 版本: {torch.__version__}")
print(f"CUDA 可用: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA 版本: {torch.version.cuda}")
    print(f"GPU 裝置: {torch.cuda.get_device_name(0)}")

# %%
import sys
# !{sys.executable} -m pip install -U monai==1.2.0
import monai
print(f"MONAI 版本: {monai.__version__}")

# %%
# !pip install -U ml_collections
# !pip install timm
# !pip install einops
# !pip install scipy
# !pip install nibabel

# %%
# !git clone https://github.com/kairaun/Sam.git

# %%
# 安裝 Sam
# %cd Sam
# !dir
# !type pyproject.toml
# !pip install -e .
# %cd ..

# %%
import sys
# !{sys.executable} -m pip install -U --no-deps monailabel
import monailabel
print(f"MONAILabel 版本: {monailabel.__version__}")

# %%
# !pip install "pydantic<2.0"

# %%
# !git clone https://github.com/kairaun/CardiacSegV2.git

# %%
# 安裝環境 (Windows 版本)
# !pip install gdown==4.6.0

# 注意：不直接安裝 requirements.txt，因為它包含舊版本的 PyTorch
# 我們會手動安裝需要的套件
print("正在安裝其他必要套件...")

# 讀取 requirements.txt 並過濾掉 PyTorch 相關套件
import os
req_file = os.path.join('CardiacSegV2', 'requirements.txt')
if os.path.exists(req_file):
    with open(req_file, 'r') as f:
        packages = [line.strip() for line in f if line.strip() and not line.startswith('#')]
    
    # 過濾掉已安裝或不相容的套件
    skip_packages = ['torch', 'torchvision', 'torchaudio', 'monai', 'monailabel']
    packages_to_install = [p for p in packages if not any(skip in p.lower() for skip in skip_packages)]
    
    print(f"將安裝以下套件: {packages_to_install}")
    for pkg in packages_to_install:
        try:
            print(f"安裝 {pkg}...")
            get_ipython().system(f'pip install {pkg}')
        except Exception as e:
            print(f"警告: {pkg} 安裝失敗 - {e}")
else:
    print("找不到 requirements.txt，跳過套件安裝")

# %%
# 修改程式碼以適應 Windows 路徑
import os

# 取得當前工作目錄
workspace_dir = os.path.abspath('CardiacSegV2')
print(f"工作目錄: {workspace_dir}")

# 讀取並修改 setup_dir.py
setup_dir_path = os.path.join(workspace_dir, 'setup_dir.py')
with open(setup_dir_path, 'r', encoding='utf-8') as f:
    content = f.read()

# 替換路徑 (使用 os.path.join 以支援 Windows)
content = content.replace('/content/CardiacSegV2/', workspace_dir.replace('\\', '/') + '/')

with open(setup_dir_path, 'w', encoding='utf-8') as f:
    f.write(content)

print("setup_dir.py 已更新")

# %%
# 修改 infer.py 和 tune.py
import os

workspace_dir = os.path.abspath('CardiacSegV2')

# 修改 infer.py
infer_path = os.path.join(workspace_dir, 'expers', 'infer.py')
if os.path.exists(infer_path):
    with open(infer_path, 'r', encoding='utf-8') as f:
        content = f.read()
    content = content.replace('sys.path.append("/content/CardiacSegV2")', 
                             f'sys.path.append("{workspace_dir.replace(chr(92), chr(92)+chr(92))}")')
    with open(infer_path, 'w', encoding='utf-8') as f:
        f.write(content)
    print("infer.py 已更新")

# 修改 tune.py
tune_path = os.path.join(workspace_dir, 'expers', 'tune.py')
if os.path.exists(tune_path):
    with open(tune_path, 'r', encoding='utf-8') as f:
        content = f.read()
    content = content.replace('sys.path.append("/content/CardiacSegV2")', 
                             f'sys.path.append("{workspace_dir.replace(chr(92), chr(92)+chr(92))}")')
    content = content.replace('ray.init(runtime_env={"working_dir": "/content/CardiacSegV2"})',
                             f'ray.init(runtime_env={{"working_dir": "{workspace_dir.replace(chr(92), chr(92)+chr(92))}"}})') 
    with open(tune_path, 'w', encoding='utf-8') as f:
        f.write(content)
    print("tune.py 已更新")

# %%
# !python CardiacSegV2\setup_dir.py

# %% [markdown]
# # 2. 設定訓練參數

# %%
import os

# 使用 Windows 風格的路徑
workspace_dir = os.path.abspath('CardiacSegV2')
model_name = 'DynUNet'
data_name = 'chgh'
exp_name = 'AICUP_training'
data_dict_file_name = 'AICUP_training.json'

# 設定實驗目錄
root_exp_dir = os.path.join(workspace_dir, 'exps', 'exps', model_name, data_name, 'tune_results')

# 設定資料目錄
root_data_dir = os.path.join(workspace_dir, 'dataset', data_name)
data_dir = root_data_dir

# data dict json 路徑
data_dicts_json = os.path.join(workspace_dir, 'exps', 'data_dicts', data_name, data_dict_file_name)

# 設定模型、日誌、評估目錄
model_dir = os.path.join('.', 'models')
log_dir = os.path.join('.', 'logs')
eval_dir = os.path.join('.', 'evals')

os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)

# 模型路徑
best_checkpoint = os.path.join(model_dir, 'best_model.pth')
final_checkpoint = os.path.join(model_dir, 'final_model.pth')

# 建立根實驗目錄
os.makedirs(root_exp_dir, exist_ok=True)

print(f"工作目錄: {workspace_dir}")
print(f"實驗目錄: {root_exp_dir}")
print(f"資料目錄: {data_dir}")
print(f"模型目錄: {model_dir}")
# Out:
# 工作目錄: d:\Felix\ML\Code\CardiacSegV2
# 實驗目錄: d:\Felix\ML\Code\CardiacSegV2\exps\exps\DynUNet\chgh\tune_results
# 資料目錄: d:\Felix\ML\Code\CardiacSegV2\dataset\chgh
# 模型目錄: .\models

# %% [markdown]
# # 3. 正式訓練
#
# 執行模型訓練，訓練參數可以根據需要調整。

# %% [markdown]
# cd D:\Felix\ML\Code\CardiacSegV2
#
# python expers/tune.py --tune_mode=train --exp_name=AICUP_training --data_name=chgh --data_dir=D:\Felix\ML\Code\CardiacSegV2\dataset\chgh --root_exp_dir=D:\Felix\ML\Code\CardiacSegV2\exps\exps\unet3d\chgh\tune_results --model_name=unet3d --model_dir=.\models --log_dir=.\logs --eval_dir=.\evals --start_epoch=0 --val_every=5 --max_early_stop_count=2 --max_epoch=20 --data_dicts_json=D:\Felix\ML\Code\CardiacSegV2\exps\data_dicts\chgh\AICUP_training.json --pin_memory --out_channels=4 --patch_size=4 --feature_size=48 --drop_rate=0.1 --depths 3 3 9 3 --kernel_size 7 --exp_rate 4 --norm_name=layer --a_min=-42 --a_max=423 --space_x=0.7 --space_y=0.7 --space_z=1.0 --roi_x=128 --roi_y=128 --roi_z=120 --optim=AdamW --lr=5e-4 --weight_decay=5e-4 --checkpoint=.\models\final_model.pth --use_init_weights --infer_post_process

# %%
# 訓練模型 (Windows 版本)
import os
import sys
import subprocess

# 確保在正確的目錄
original_dir = os.getcwd()
os.chdir(workspace_dir)

print(f"當前工作目錄: {os.getcwd()}")
print("開始訓練...\n")

# 建構訓練命令
train_cmd = [
    sys.executable, "expers/tune.py",
    "--tune_mode=train",
    f"--exp_name={exp_name}",
    f"--data_name={data_name}",
    f"--data_dir={data_dir}",
    f"--root_exp_dir={root_exp_dir}",
    f"--model_name={model_name}",
    f"--model_dir={model_dir}",
    f"--log_dir={log_dir}",
    f"--eval_dir={eval_dir}",
    "--start_epoch=0",
    "--val_every=5",
    "--max_early_stop_count=2",
    "--max_epoch=20",
    f"--data_dicts_json={data_dicts_json}",
    "--pin_memory",
    "--out_channels=4",
    "--patch_size=4",
    "--feature_size=48",
    "--drop_rate=0.1",
    "--depths", "3", "3", "9", "3",
    "--kernel_size", "7",
    "--exp_rate", "4",
    "--norm_name=layer",
    "--a_min=-42",
    "--a_max=423",
    "--space_x=0.7",
    "--space_y=0.7",
    "--space_z=1.0",
    "--roi_x=128",
    "--roi_y=128",
    "--roi_z=128",  # 修改為 128 (2的冪次方) 以避免尺寸不匹配錯誤
    "--optim=AdamW",
    "--lr=5e-4",
    "--weight_decay=5e-4",
    f"--checkpoint={final_checkpoint}",
    "--use_init_weights",
    "--infer_post_process"
]

print("執行命令:")
print(" ".join(train_cmd))
print("\n" + "="*80 + "\n")

# 使用 Popen 來即時顯示輸出
process = subprocess.Popen(
    train_cmd,
    cwd=workspace_dir,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    universal_newlines=True
)

# 即時打印輸出
for line in process.stdout:
    print(line, end='')

# 等待程序完成
return_code = process.wait()

# 切回原始目錄
os.chdir(original_dir)

print("\n" + "="*80)
if return_code == 0:
    print("\n✅ 訓練完成！")
    print(f"最佳模型已儲存至: {best_checkpoint}")
    print(f"最終模型已儲存至: {final_checkpoint}")
else:
    print(f"\n❌ 訓練失敗，錯誤碼: {return_code}")
    print("請查看上方的錯誤訊息以了解失敗原因")
# Out:
# 當前工作目錄: d:\Felix\ML\Code\CardiacSegV2
# 開始訓練...
#
# 執行命令:
# d:\Felix\ML\Code\.conda\python.exe expers/tune.py --tune_mode=train --exp_name=AICUP_training --data_name=chgh --data_dir=d:\Felix\ML\Code\CardiacSegV2\dataset\chgh --root_exp_dir=d:\Felix\ML\Code\CardiacSegV2\exps\exps\DynUNet\chgh\tune_results --model_name=DynUNet --model_dir=.\models --log_dir=.\logs --eval_dir=.\evals --start_epoch=0 --val_every=5 --max_early_stop_count=2 --max_epoch=20 --data_dicts_json=d:\Felix\ML\Code\CardiacSegV2\exps\data_dicts\chgh\AICUP_training.json --pin_memory --out_channels=4 --patch_size=4 --feature_size=48 --drop_rate=0.1 --depths 3 3 9 3 --kernel_size 7 --exp_rate 4 --norm_name=layer --a_min=-42 --a_max=423 --space_x=0.7 --space_y=0.7 --space_z=1.0 --roi_x=128 --roi_y=128 --roi_z=128 --optim=AdamW --lr=5e-4 --weight_decay=5e-4 --checkpoint=.\models\final_model.pth --use_init_weights --infer_post_process
#
# ================================================================================
#
# Importing from timm.models.layers is deprecated, please import via timm.layers
# Importing from timm.models.registry is deprecated, please import via timm.models
# Setting a `RunConfig.local_dir` is deprecated and will be removed in the future. If you are not using remote storage,set the `RunConfig.storage_path` instead. Otherwise, set the`RAY_AIR_LOCAL_CACHE_DIR` environment variable to control the local cache location.
# Importing from timm.models.layers is deprecated, please import via timm.layers
# Importing from timm.models.registry is deprecated, please import via timm.models
# Setting a `RunConfig.local_dir` is deprecated and will be removed in the future. If you are not using remote storage,set the `RunConfig.storage_path` instead. Otherwise, set the`RAY_AIR_LOCAL_CACHE_DIR` environment variable to control the local cache location.
# 2025-10-16 21:14:26,533	INFO worker.py:1621 -- Started a local Ray instance.
# 2025-10-16 21:14:26,533	INFO worker.py:1621 -- Started a local Ray instance.
# 2025-10-16 21:14:27,993	INFO tune.py:226 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# 2025-10-16 21:14:27,994	INFO tune.py:666 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2025-10-16 21:14:28,000	INFO tensorboardx.py:178 -- pip install "ray[tune]" to see TensorBoard files.
# 2025-10-16 21:14:28,000	WARNING callback.py:144 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# 2025-10-16 21:14:28,001	WARNING tune.py:997 -- AIR_VERBOSITY is set, ignoring passed-in ProgressReporter for now.
# ╭────────────────────────────────────────────────────────╮
# │ Configuration for experiment     AICUP_training        │
# ├────────────────────────────────────────────────────────┤
# │ Search algorithm                 BasicVariantGenerator │
# │ Scheduler                        FIFOScheduler         │
# │ Number of trials                 1                     │
# ╰────────────────────────────────────────────────────────╯
#
# View detailed results here: d://\Felix\ML\Code\CardiacSegV2\exps\exps\DynUNet\chgh\tune_results\AICUP_training
#
# Trial status: 1 PENDING
# Current time: 2025-10-16 21:14:28. Total running time: 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   PENDING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# 2025-10-16 21:14:27,993	INFO tune.py:226 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# 2025-10-16 21:14:27,994	INFO tune.py:666 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2025-10-16 21:14:28,000	INFO tensorboardx.py:178 -- pip install "ray[tune]" to see TensorBoard files.
# 2025-10-16 21:14:28,000	WARNING callback.py:144 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# 2025-10-16 21:14:28,001	WARNING tune.py:997 -- AIR_VERBOSITY is set, ignoring passed-in ProgressReporter for now.
# ╭────────────────────────────────────────────────────────╮
# │ Configuration for experiment     AICUP_training        │
# ├────────────────────────────────────────────────────────┤
# │ Search algorithm                 BasicVariantGenerator │
# │ Scheduler                        FIFOScheduler         │
# │ Number of trials                 1                     │
# ╰────────────────────────────────────────────────────────╯
#
# View detailed results here: d://\Felix\ML\Code\CardiacSegV2\exps\exps\DynUNet\chgh\tune_results\AICUP_training
#
# Trial status: 1 PENDING
# Current time: 2025-10-16 21:14:28. Total running time: 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   PENDING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# (pid=23140) Importing from timm.models.layers is deprecated, please import via timm.layers
# (pid=23140) Importing from timm.models.registry is deprecated, please import via timm.models
# Training started with configuration:
# ╭────────────────────────────────────╮
# │ Training config                    │
# ├────────────────────────────────────┤
# │ exp/exp             AICUP_training │
# ╰────────────────────────────────────╯
#
# (func pid=23140) a_max 423.0
# (func pid=23140) a_min -42.0
# (func pid=23140) space_x 0.7
# (func pid=23140) roi_x 128
# (func pid=23140) lr 0.0005
# (func pid=23140) weight_decay 0.0005
# (func pid=23140) warmup_epochs 50
# (func pid=23140) max_epochs 20
# (func pid=23140) cuda is available
# (func pid=23140) model: DynUNet
# (pid=23140) Importing from timm.models.layers is deprecated, please import via timm.layers
# (pid=23140) Importing from timm.models.registry is deprecated, please import via timm.models
# Training started with configuration:
# ╭────────────────────────────────────╮
# │ Training config                    │
# ├────────────────────────────────────┤
# │ exp/exp             AICUP_training │
# ╰────────────────────────────────────╯
#
# (func pid=23140) a_max 423.0
# (func pid=23140) a_min -42.0
# (func pid=23140) space_x 0.7
# (func pid=23140) roi_x 128
# (func pid=23140) lr 0.0005
# (func pid=23140) weight_decay 0.0005
# (func pid=23140) warmup_epochs 50
# (func pid=23140) max_epochs 20
# (func pid=23140) cuda is available
# (func pid=23140) model: DynUNet
# (func pid=23140) monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# (func pid=23140) <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# (func pid=23140) monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# (func pid=23140)
# Loading dataset:   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140) loss: dice ce loss
# (func pid=23140) optimzer: AdamW
# (func pid=23140) {'lr': 0.0005, 'weight_decay': 0.0005}
# (func pid=23140) load json from d:\Felix\ML\Code\CardiacSegV2\exps\data_dicts\chgh\AICUP_training.json
# (func pid=23140) train files (9): ['patient0011', 'patient0012', 'patient0013', 'patient0014', 'patient0015', 'patient0016', 'patient0017', 'patient0018', 'patient0019']
# (func pid=23140) val files (3): ['patient0048', 'patient0049', 'patient0050']
# (func pid=23140) test files (3): ['patient0001', 'patient0002', 'patient0003']
# (func pid=23140)
# (func pid=23140) load train dataset ...
# (func pid=23140) Using MONAI Cache Dataset
# (func pid=23140) monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# (func pid=23140) <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# (func pid=23140) monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# (func pid=23140)
# Loading dataset:   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140) loss: dice ce loss
# (func pid=23140) optimzer: AdamW
# (func pid=23140) {'lr': 0.0005, 'weight_decay': 0.0005}
# (func pid=23140) load json from d:\Felix\ML\Code\CardiacSegV2\exps\data_dicts\chgh\AICUP_training.json
# (func pid=23140) train files (9): ['patient0011', 'patient0012', 'patient0013', 'patient0014', 'patient0015', 'patient0016', 'patient0017', 'patient0018', 'patient0019']
# (func pid=23140) val files (3): ['patient0048', 'patient0049', 'patient0050']
# (func pid=23140) test files (3): ['patient0001', 'patient0002', 'patient0003']
# (func pid=23140)
# (func pid=23140) load train dataset ...
# (func pid=23140) Using MONAI Cache Dataset
# (func pid=23140)
# Loading dataset:  11%|█         | 1/9 [00:04<00:34,  4.37s/it]
# (func pid=23140)
# Loading dataset:  11%|█         | 1/9 [00:04<00:34,  4.37s/it]
# (func pid=23140)
# Loading dataset:  22%|██▏       | 2/9 [00:06<00:21,  3.00s/it]
# (func pid=23140)
# Loading dataset:  22%|██▏       | 2/9 [00:06<00:21,  3.00s/it]
# (func pid=23140)
# Loading dataset:  33%|███▎      | 3/9 [00:10<00:20,  3.37s/it]
# (func pid=23140)
# Loading dataset:  33%|███▎      | 3/9 [00:10<00:20,  3.37s/it]
# (func pid=23140)
# Loading dataset:  44%|████▍     | 4/9 [00:11<00:11,  2.36s/it]
# (func pid=23140)
# Loading dataset:  44%|████▍     | 4/9 [00:11<00:11,  2.36s/it]
# (func pid=23140)
# Loading dataset:  56%|█████▌    | 5/9 [00:15<00:12,  3.11s/it]
# (func pid=23140)
# Loading dataset:  56%|█████▌    | 5/9 [00:15<00:12,  3.11s/it]
# (func pid=23140)
# Loading dataset:  67%|██████▋   | 6/9 [00:18<00:08,  2.99s/it]
# (func pid=23140)
# Loading dataset:  67%|██████▋   | 6/9 [00:18<00:08,  2.99s/it]
# (func pid=23140)
# Loading dataset:  78%|███████▊  | 7/9 [00:21<00:06,  3.02s/it]
# (func pid=23140)
# Loading dataset:  78%|███████▊  | 7/9 [00:21<00:06,  3.02s/it]
# (func pid=23140)
# Loading dataset:  89%|████████▉ | 8/9 [00:22<00:02,  2.57s/it]
# (func pid=23140)
# Loading dataset:  89%|████████▉ | 8/9 [00:22<00:02,  2.57s/it]
# Trial status: 1 RUNNING
# Current time: 2025-10-16 21:14:58. Total running time: 30s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 21:14:58. Total running time: 30s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# (func pid=23140)
# Loading dataset: 100%|██████████| 9/9 [00:27<00:00,  3.20s/it]
# Loading dataset: 100%|██████████| 9/9 [00:27<00:00,  3.06s/it]
# (func pid=23140)
# Loading dataset:   0%|          | 0/3 [00:00<?, ?it/s]
# (func pid=23140)
# (func pid=23140) load val dataset ...
# (func pid=23140) Using MONAI Cache Dataset
# (func pid=23140)
# Loading dataset: 100%|██████████| 9/9 [00:27<00:00,  3.20s/it]
# Loading dataset: 100%|██████████| 9/9 [00:27<00:00,  3.06s/it]
# (func pid=23140)
# Loading dataset:   0%|          | 0/3 [00:00<?, ?it/s]
# (func pid=23140)
# (func pid=23140) load val dataset ...
# (func pid=23140) Using MONAI Cache Dataset
# (func pid=23140)
# Loading dataset:  33%|███▎      | 1/3 [00:06<00:12,  6.35s/it]
# (func pid=23140)
# Loading dataset:  33%|███▎      | 1/3 [00:06<00:12,  6.35s/it]
# (func pid=23140)
# Loading dataset: 100%|██████████| 3/3 [00:11<00:00,  3.43s/it]
# Loading dataset: 100%|██████████| 3/3 [00:11<00:00,  3.72s/it]
# (func pid=23140)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140)
# Loading dataset: 100%|██████████| 3/3 [00:11<00:00,  3.43s/it]
# Loading dataset: 100%|██████████| 3/3 [00:11<00:00,  3.72s/it]
# (func pid=23140)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140)
# [Epoch 0] Training (0 Steps) (loss=2.47854):   0%|          | 0/9 [00:10<?, ?it/s]
# [Epoch 0] Training (0 Steps) (loss=2.47854):  11%|█         | 1/9 [00:10<01:20, 10.11s/it]
# (func pid=23140)
# [Epoch 0] Training (0 Steps) (loss=2.47854):   0%|          | 0/9 [00:10<?, ?it/s]
# [Epoch 0] Training (0 Steps) (loss=2.47854):  11%|█         | 1/9 [00:10<01:20, 10.11s/it]
# (func pid=23140)
# [Epoch 0] Training (1 Steps) (loss=2.45400):  11%|█         | 1/9 [00:10<01:20, 10.11s/it]
# [Epoch 0] Training (1 Steps) (loss=2.45400):  22%|██▏       | 2/9 [00:10<00:30,  4.40s/it]
# (func pid=23140)
# [Epoch 0] Training (1 Steps) (loss=2.45400):  11%|█         | 1/9 [00:10<01:20, 10.11s/it]
# [Epoch 0] Training (1 Steps) (loss=2.45400):  22%|██▏       | 2/9 [00:10<00:30,  4.40s/it]
# (func pid=23140)
# [Epoch 0] Training (2 Steps) (loss=2.39162):  22%|██▏       | 2/9 [00:10<00:30,  4.40s/it]
# [Epoch 0] Training (2 Steps) (loss=2.39162):  33%|███▎      | 3/9 [00:10<00:15,  2.53s/it]
# (func pid=23140)
# [Epoch 0] Training (2 Steps) (loss=2.39162):  22%|██▏       | 2/9 [00:10<00:30,  4.40s/it]
# [Epoch 0] Training (2 Steps) (loss=2.39162):  33%|███▎      | 3/9 [00:10<00:15,  2.53s/it]
# (func pid=23140)
# [Epoch 5] Training (50 Steps) (loss=1.64421):  67%|██████▋   | 6/9 [00:10<00:02,  1.28it/s]
# (func pid=23140)
# [Epoch 5] Training (51 Steps) (loss=1.63820):  67%|██████▋   | 6/9 [00:10<00:02,  1.28it/s]
# [Epoch 5] Training (51 Steps) (loss=1.63820):  78%|███████▊  | 7/9 [00:10<00:01,  1.62it/s]
# (func pid=23140)
# [Epoch 5] Training (51 Steps) (loss=1.63820):  67%|██████▋   | 6/9 [00:10<00:02,  1.28it/s]
# [Epoch 5] Training (51 Steps) (loss=1.63820):  78%|███████▊  | 7/9 [00:10<00:01,  1.62it/s]
# (func pid=23140)
# [Epoch 5] Training (52 Steps) (loss=1.62710):  78%|███████▊  | 7/9 [00:11<00:01,  1.62it/s]
# [Epoch 5] Training (52 Steps) (loss=1.62710):  89%|████████▉ | 8/9 [00:11<00:00,  1.92it/s]
# (func pid=23140)
# [Epoch 5] Training (52 Steps) (loss=1.62710):  78%|███████▊  | 7/9 [00:11<00:01,  1.62it/s]
# [Epoch 5] Training (52 Steps) (loss=1.62710):  89%|████████▉ | 8/9 [00:11<00:00,  1.92it/s]
# (func pid=23140)
# [Epoch 5] Training (53 Steps) (loss=1.64403):  89%|████████▉ | 8/9 [00:11<00:00,  1.92it/s]
# [Epoch 5] Training (53 Steps) (loss=1.64403): 100%|██████████| 9/9 [00:11<00:00,  2.27it/s]
# (func pid=23140)
# [Epoch 5] Training (53 Steps) (loss=1.64403):  89%|████████▉ | 8/9 [00:11<00:00,  1.92it/s]
# [Epoch 5] Training (53 Steps) (loss=1.64403): 100%|██████████| 9/9 [00:11<00:00,  2.27it/s]
# (func pid=23140)
# [Epoch 5] Training (53 Steps) (loss=1.64403): 100%|██████████| 9/9 [00:11<00:00,  1.32s/it]
# (func pid=23140)
# Validate (X / X Steps) (dice=X.X):   0%|          | 0/3 [00:00<?, ?it/s]
# (func pid=23140)
# [Epoch 5] Training (53 Steps) (loss=1.64403): 100%|██████████| 9/9 [00:11<00:00,  1.32s/it]
# (func pid=23140)
# Validate (X / X Steps) (dice=X.X):   0%|          | 0/3 [00:00<?, ?it/s]
# Trial status: 1 RUNNING
# Current time: 2025-10-16 21:16:28. Total running time: 2min 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 21:16:28. Total running time: 2min 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭────────────────────────────────────────────────────╮
# │ Trial name         status     exp                  │
# ├────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   RUNNING    ...'AICUP_training'} │
# ╰────────────────────────────────────────────────────╯
#
# (func pid=23140)
# Validate (54 / 10 Steps):   0%|          | 0/3 [00:05<?, ?it/s]
# Validate (54 / 10 Steps):  33%|███▎      | 1/3 [00:05<00:10,  5.28s/it]
# (func pid=23140)
# Validate (54 / 10 Steps):   0%|          | 0/3 [00:05<?, ?it/s]
# Validate (54 / 10 Steps):  33%|███▎      | 1/3 [00:05<00:10,  5.28s/it]
# (func pid=23140)
# Validate (54 / 10 Steps):  33%|███▎      | 1/3 [00:05<00:10,  5.28s/it]
# Validate (54 / 10 Steps):  67%|██████▋   | 2/3 [00:05<00:02,  2.49s/it]
# (func pid=23140)
# Validate (54 / 10 Steps):  33%|███▎      | 1/3 [00:05<00:10,  5.28s/it]
# Validate (54 / 10 Steps):  67%|██████▋   | 2/3 [00:05<00:02,  2.49s/it]
# (func pid=23140)
# Validate (54 / 10 Steps):  67%|██████▋   | 2/3 [00:06<00:02,  2.49s/it]
# Validate (54 / 10 Steps): 100%|██████████| 3/3 [00:06<00:00,  1.61s/it]
# (func pid=23140)
# Validate (54 / 10 Steps):  67%|██████▋   | 2/3 [00:06<00:02,  2.49s/it]
# Validate (54 / 10 Steps): 100%|██████████| 3/3 [00:06<00:00,  1.61s/it]
# (func pid=23140)
# Validate (54 / 10 Steps): 100%|██████████| 3/3 [00:07<00:00,  2.36s/it]
# (func pid=23140)
# Validate (54 / 10 Steps): 100%|██████████| 3/3 [00:07<00:00,  2.36s/it]
# (func pid=23140) Saving checkpoint .\models\best_model.pth
# (func pid=23140) Best Model Was Saved ! Current Best Avg. Dice: 0.39964058995246887 Current Avg. Dice: 0.39964058995246887
# Training finished iteration 1 at 2025-10-16 21:16:34. Total running time: 2min 6s
# ╭──────────────────────────────╮
# │ Training result              │
# ├──────────────────────────────┤
# │ time_this_iter_s     121.126 │
# │ time_total_s         121.126 │
# │ training_iteration         1 │
# │ esc                        0 │
# │ tt_dice                    0 │
# │ tt_iou                     0 │
# │ val_bst_acc          0.39964 │
# ╰──────────────────────────────╯
#
# (func pid=23140)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140) Saving checkpoint .\models\final_model.pth
# (func pid=23140) Final Model Was Saved ! Current Best Avg. Dice: 0.39964058995246887 Current Avg. Dice: 0.39964058995246887
# (func pid=23140) Saving checkpoint .\models\best_model.pth
# (func pid=23140) Best Model Was Saved ! Current Best Avg. Dice: 0.39964058995246887 Current Avg. Dice: 0.39964058995246887
# Training finished iteration 1 at 2025-10-16 21:16:34. Total running time: 2min 6s
# ╭──────────────────────────────╮
# │ Training result              │
# ├──────────────────────────────┤
# │ time_this_iter_s     121.126 │
# │ time_total_s         121.126 │
# │ training_iteration         1 │
# │ esc                        0 │
# │ tt_dice                    0 │
# │ tt_iou                     0 │
# │ val_bst_acc          0.39964 │
# ╰──────────────────────────────╯
#
# (func pid=23140)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140) Saving checkpoint .\models\final_model.pth
# (func pid=23140) Final Model Was Saved ! Current Best Avg. Dice: 0.39964058995246887 Current Avg. Dice: 0.39964058995246887
# (func pid=23140)
# [Epoch 6] Training (54 Steps) (loss=1.67744):   0%|          | 0/9 [00:09<?, ?it/s]
# [Epoch 6] Training (54 Steps) (loss=1.67744):  11%|█         | 1/9 [00:09<01:12,  9.04s/it]
# (func pid=23140)
# [Epoch 6] Training (55 Steps) (loss=1.58414):  11%|█         | 1/9 [00:09<01:12,  9.04s/it]
# [Epoch 6] Training (55 Steps) (loss=1.58414):  22%|██▏       | 2/9 [00:09<00:27,  3.88s/it]
# (func pid=23140)
# [Epoch 6] Training (54 Steps) (loss=1.67744):   0%|          | 0/9 [00:09<?, ?it/s]
# [Epoch 6] Training (54 Steps) (loss=1.67744):  11%|█         | 1/9 [00:09<01:12,  9.04s/it]
# (func pid=23140)
# [Epoch 6] Training (55 Steps) (loss=1.58414):  11%|█         | 1/9 [00:09<01:12,  9.04s/it]
# [Epoch 6] Training (55 Steps) (loss=1.58414):  22%|██▏       | 2/9 [00:09<00:27,  3.88s/it]
# (func pid=23140)
# [Epoch 6] Training (56 Steps) (loss=1.58700):  22%|██▏       | 2/9 [00:09<00:27,  3.88s/it]
# [Epoch 6] Training (56 Steps) (loss=1.58700):  33%|███▎      | 3/9 [00:09<00:13,  2.25s/it]
# (func pid=23140)
# [Epoch 6] Training (56 Steps) (loss=1.58700):  22%|██▏       | 2/9 [00:09<00:27,  3.88s/it]
# [Epoch 6] Training (56 Steps) (loss=1.58700):  33%|███▎      | 3/9 [00:09<00:13,  2.25s/it]
# (func pid=23140)
# [Epoch 6] Training (57 Steps) (loss=1.56950):  33%|███▎      | 3/9 [00:09<00:13,  2.25s/it]
# [Epoch 6] Training (57 Steps) (loss=1.56950):  44%|████▍     | 4/9 [00:09<00:07,  1.47s/it]
# (func pid=23140)
# [Epoch 6] Training (57 Steps) (loss=1.56950):  33%|███▎      | 3/9 [00:09<00:13,  2.25s/it]
# [Epoch 6] Training (57 Steps) (loss=1.56950):  44%|████▍     | 4/9 [00:09<00:07,  1.47s/it]
# (func pid=23140)
# [Epoch 6] Training (58 Steps) (loss=1.68306):  44%|████▍     | 4/9 [00:10<00:07,  1.47s/it]
# [Epoch 6] Training (58 Steps) (loss=1.68306):  56%|█████▌    | 5/9 [00:10<00:04,  1.04s/it]
# (func pid=23140)
# [Epoch 6] Training (58 Steps) (loss=1.68306):  44%|████▍     | 4/9 [00:10<00:07,  1.47s/it]
# [Epoch 6] Training (58 Steps) (loss=1.68306):  56%|█████▌    | 5/9 [00:10<00:04,  1.04s/it]
# (func pid=23140)
# [Epoch 6] Training (59 Steps) (loss=1.54347):  56%|█████▌    | 5/9 [00:10<00:04,  1.04s/it]
# [Epoch 6] Training (59 Steps) (loss=1.54347):  67%|██████▋   | 6/9 [00:10<00:02,  1.27it/s]
# (func pid=23140)
# [Epoch 6] Training (59 Steps) (loss=1.54347):  56%|█████▌    | 5/9 [00:10<00:04,  1.04s/it]
# [Epoch 6] Training (59 Steps) (loss=1.54347):  67%|██████▋   | 6/9 [00:10<00:02,  1.27it/s]
# (func pid=23140)
# [Epoch 6] Training (60 Steps) (loss=1.62481):  67%|██████▋   | 6/9 [00:10<00:02,  1.27it/s]
# [Epoch 6] Training (60 Steps) (loss=1.62481):  78%|███████▊  | 7/9 [00:10<00:01,  1.58it/s]
# (func pid=23140)
# [Epoch 6] Training (60 Steps) (loss=1.62481):  67%|██████▋   | 6/9 [00:10<00:02,  1.27it/s]
# [Epoch 6] Training (60 Steps) (loss=1.62481):  78%|███████▊  | 7/9 [00:10<00:01,  1.58it/s]
# (func pid=23140)
# [Epoch 6] Training (61 Steps) (loss=1.62665):  78%|███████▊  | 7/9 [00:11<00:01,  1.58it/s]
# [Epoch 6] Training (61 Steps) (loss=1.62665):  89%|████████▉ | 8/9 [00:11<00:00,  1.90it/s]
# (func pid=23140)
# [Epoch 6] Training (61 Steps) (loss=1.62665):  78%|███████▊  | 7/9 [00:11<00:01,  1.58it/s]
# [Epoch 6] Training (61 Steps) (loss=1.62665):  89%|████████▉ | 8/9 [00:11<00:00,  1.90it/s]
# (func pid=23140)
# [Epoch 6] Training (62 Steps) (loss=1.54471):  89%|████████▉ | 8/9 [00:11<00:00,  1.90it/s]
# [Epoch 6] Training (62 Steps) (loss=1.54471): 100%|██████████| 9/9 [00:11<00:00,  2.20it/s]
# (func pid=23140)
# [Epoch 6] Training (62 Steps) (loss=1.54471):  89%|████████▉ | 8/9 [00:11<00:00,  1.90it/s]
# [Epoch 6] Training (62 Steps) (loss=1.54471): 100%|██████████| 9/9 [00:11<00:00,  2.20it/s]
# (func pid=23140)
# [Epoch 6] Training (62 Steps) (loss=1.54471): 100%|██████████| 9/9 [00:12<00:00,  1.34s/it]
# (func pid=23140)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140)
# [Epoch 6] Training (62 Steps) (loss=1.54471): 100%|██████████| 9/9 [00:12<00:00,  1.34s/it]
# (func pid=23140)
# Training (X / X Steps) (loss=X.X):   0%|          | 0/9 [00:00<?, ?it/s]
# (func pid=23140)
# [Epoch 7] Training (63 Steps) (loss=1.60716):   0%|          | 0/9 [00:09<?, ?it/s]
# [Epoch 7] Training (63 Steps) (loss=1.60716):  11%|█         | 1/9 [00:09<01:12,  9.02s/it]
# (func pid=23140)
# [Epoch 7] Training (63 Steps) (loss=1.60716):   0%|          | 0/9 [00:09<?, ?it/s]
# [Epoch 7] Training (63 Steps) (loss=1.60716):  11%|█         | 1/9 [00:09<01:12,  9.02s/it]
# (func pid=23140)
# [Epoch 7] Training (64 Steps) (loss=1.47314):  11%|█         | 1/9 [00:09<01:12,  9.02s/it]
# [Epoch 7] Training (64 Steps) (loss=1.47314):  22%|██▏       | 2/9 [00:09<00:27,  3.89s/it]
# (func pid=23140)
# [Epoch 7] Training (64 Steps) (loss=1.47314):  11%|█         | 1/9 [00:09<01:12,  9.02s/it]
# [Epoch 7] Training (64 Steps) (loss=1.47314):  22%|██▏       | 2/9 [00:09<00:27,  3.89s/it]
# (func pid=23140)
# [Epoch 7] Training (65 Steps) (loss=1.60351):  22%|██▏       | 2/9 [00:09<00:27,  3.89s/it]
# [Epoch 7] Training (65 Steps) (loss=1.60351):  33%|███▎      | 3/9 [00:09<00:13,  2.26s/it]
# ...
# (func pid=23140) sensitivity: [0.8676339 0.        0.       ]
# (func pid=23140) specificity: [0.9696047  1.         0.99999946]
# (func pid=23140) infer data: {'image': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0002.nii.gz', 'label': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0002_gt.nii.gz'}
# (func pid=23140) infer time: 0.27693819999694824 sec
# (func pid=23140) use post process infer
# (func pid=23140) infer time: 0.27693819999694824 sec
# (func pid=23140) use post process infer
# (func pid=23140) invalid value encountered in divide
# (func pid=23140) Confusion_Vals： [[4.8889400e+05 3.9189900e+05 1.4611627e+07 8.5905000e+04]
# (func pid=23140)  [0.0000000e+00 0.0000000e+00 1.5567919e+07 1.0406000e+04]
# (func pid=23140)  [0.0000000e+00 1.3000000e+01 1.5578312e+07 0.0000000e+00]]
# (func pid=23140) infer test time aug:
# (func pid=23140) dice: [0.67174596 0.                nan]
# (func pid=23140) iou: [0.505736 0.            nan]
# (func pid=23140) invalid value encountered in divide
# (func pid=23140) Confusion_Vals： [[4.8889400e+05 3.9189900e+05 1.4611627e+07 8.5905000e+04]
# (func pid=23140)  [0.0000000e+00 0.0000000e+00 1.5567919e+07 1.0406000e+04]
# (func pid=23140)  [0.0000000e+00 1.3000000e+01 1.5578312e+07 0.0000000e+00]]
# (func pid=23140) infer test time aug:
# (func pid=23140) dice: [0.67174596 0.                nan]
# (func pid=23140) iou: [0.505736 0.            nan]
# (func pid=23140) Confusion_Vals： [[3.2831090e+06 2.5096960e+06 9.6154192e+07 5.5130500e+05]
# (func pid=23140)  [0.0000000e+00 0.0000000e+00 1.0243005e+08 6.8256000e+04]
# (func pid=23140)  [0.0000000e+00 9.6000000e+01 1.0249821e+08 0.0000000e+00]]
# (func pid=23140) infer test original:
# (func pid=23140) dice: [0.6820474 0.              nan]
# (func pid=23140) iou: [0.5175053 0.              nan]
# (func pid=23140) sensitivity: [0.85622185 0.                nan]
# (func pid=23140) specificity: [0.9745632  1.         0.99999905]
# (func pid=23140) infer data: {'image': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0003.nii.gz', 'label': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0003_gt.nii.gz'}
# (func pid=23140) Confusion_Vals： [[3.2831090e+06 2.5096960e+06 9.6154192e+07 5.5130500e+05]
# (func pid=23140)  [0.0000000e+00 0.0000000e+00 1.0243005e+08 6.8256000e+04]
# (func pid=23140)  [0.0000000e+00 9.6000000e+01 1.0249821e+08 0.0000000e+00]]
# (func pid=23140) infer test original:
# (func pid=23140) dice: [0.6820474 0.              nan]
# (func pid=23140) iou: [0.5175053 0.              nan]
# (func pid=23140) sensitivity: [0.85622185 0.                nan]
# (func pid=23140) specificity: [0.9745632  1.         0.99999905]
# (func pid=23140) infer data: {'image': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0003.nii.gz', 'label': 'd:\\Felix\\ML\\Code\\CardiacSegV2\\dataset\\chgh\\patient0003_gt.nii.gz'}
# (func pid=23140) infer time: 0.3338301181793213 sec
# (func pid=23140) use post process infer
# (func pid=23140) infer time: 0.3338301181793213 sec
# (func pid=23140) use post process infer
# (func pid=23140) Confusion_Vals： [[5.0490200e+05 8.6245800e+05 1.5006676e+07 1.1124600e+05]
# (func pid=23140)  [0.0000000e+00 1.0000000e+00 1.6472528e+07 1.2753000e+04]
# (func pid=23140)  [0.0000000e+00 2.9000000e+01 1.6485253e+07 0.0000000e+00]]
# (func pid=23140) infer test time aug:
# (func pid=23140) dice: [0.5091 0.        nan]
# (func pid=23140) iou: [0.34147164 0.                nan]
# (func pid=23140) Confusion_Vals： [[5.0490200e+05 8.6245800e+05 1.5006676e+07 1.1124600e+05]
# (func pid=23140)  [0.0000000e+00 1.0000000e+00 1.6472528e+07 1.2753000e+04]
# (func pid=23140)  [0.0000000e+00 2.9000000e+01 1.6485253e+07 0.0000000e+00]]
# (func pid=23140) infer test time aug:
# (func pid=23140) dice: [0.5091 0.        nan]
# (func pid=23140) iou: [0.34147164 0.                nan]
# Trial status: 1 RUNNING
# Current time: 2025-10-16 21:20:28. Total running time: 6min 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   RUNNING    ...'AICUP_training'}        4            326.048           0          0         0.46566       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING
# Current time: 2025-10-16 21:20:28. Total running time: 6min 0s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status     exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc     esc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   RUNNING    ...'AICUP_training'}        4            326.048           0          0         0.46566       0 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# (func pid=23140) Confusion_Vals： [[2.620877e+06 4.420400e+06 7.731731e+07 5.760690e+05]
# (func pid=23140)  [0.000000e+00 8.000000e+00 8.486849e+07 6.616100e+04]
# (func pid=23140)  [0.000000e+00 1.840000e+02 8.493447e+07 0.000000e+00]]
# (func pid=23140) infer test original:
# (func pid=23140) dice: [0.51197904 0.                nan]
# (func pid=23140) iou: [0.3440671 0.              nan]
# (func pid=23140) sensitivity: [0.81980646 0.                nan]
# (func pid=23140) specificity: [0.9459197  0.9999999  0.99999785]
# (func pid=23140)
# (func pid=23140) eval result:
# (func pid=23140) avg tt dice: 0.26818952
# (func pid=23140) avg tt iou: 0.19378215
# (func pid=23140) avg inf dice: 0.27123788
# (func pid=23140) avg inf iou: 0.19710569
# (func pid=23140) avg inf sensitivity: 0.3757418
# (func pid=23140) avg inf specificity: 0.98778707
# (func pid=23140) avg inf time: 0.2598252296447754
# Training finished iteration 5 at 2025-10-16 21:20:31. Total running time: 6min 3s
# ╭───────────────────────────────╮
# │ Training result               │
# ├───────────────────────────────┤
# │ time_this_iter_s      31.3572 │
# │ time_total_s          357.405 │
# │ training_iteration          5 │
# │ inf_dice             0.271238 │
# │ inf_iou              0.197106 │
# │ inf_time              0.25983 │
# │ tt_dice               0.26819 │
# │ tt_iou               0.193782 │
# │ val_bst_acc           0.46566 │
# ╰───────────────────────────────╯
#
# (func pid=23140)      patientId  tt_diceC  tt_diceAO  tt_diceCA   tt_iouC  tt_iouAO  tt_iouCA  inf_diceC  inf_diceAO  inf_diceCA  inf_iouC  inf_iouAO  inf_iouCA  inf_sensitivityC  inf_sensitivityAO  inf_sensitivityCA  inf_specificityC  inf_specificityAO  inf_specificityCA  inf_time
# (func pid=23140) 0  patient0001  0.642437        0.0        0.0  0.473228       0.0       0.0   0.650101         0.0         0.0  0.481593        0.0        0.0          0.867634                0.0                0.0          0.969605                1.0           0.999999  0.168707
# (func pid=23140) 1  patient0002  0.671746        0.0        NaN  0.505736       0.0       NaN   0.682047         0.0         NaN  0.517505        0.0        NaN          0.856222                0.0                NaN          0.974563                1.0           0.999999  0.276938
# (func pid=23140) 2  patient0003  0.509100        0.0        NaN  0.341472       0.0       NaN   0.511979         0.0         NaN  0.344067        0.0        NaN          0.819806                0.0                NaN          0.945920                1.0           0.999998  0.333830
# Training completed after 5 iterations at 2025-10-16 21:20:31. Total running time: 6min 3s
#
# 2025-10-16 21:20:31,038	WARNING tune.py:1122 -- Trial Runner checkpointing failed: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training', which is outside base dir 'C:\Users\User\ray_results\AICUP_training'
# Trial status: 1 TERMINATED
# Current time: 2025-10-16 21:20:31. Total running time: 6min 3s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status       exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   TERMINATED   ...'AICUP_training'}        5            357.405     0.26819   0.193782         0.46566 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# (func pid=23140) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23140) Confusion_Vals： [[2.620877e+06 4.420400e+06 7.731731e+07 5.760690e+05]
# (func pid=23140)  [0.000000e+00 8.000000e+00 8.486849e+07 6.616100e+04]
# (func pid=23140)  [0.000000e+00 1.840000e+02 8.493447e+07 0.000000e+00]]
# (func pid=23140) infer test original:
# (func pid=23140) dice: [0.51197904 0.                nan]
# (func pid=23140) iou: [0.3440671 0.              nan]
# (func pid=23140) sensitivity: [0.81980646 0.                nan]
# (func pid=23140) specificity: [0.9459197  0.9999999  0.99999785]
# (func pid=23140)
# (func pid=23140) eval result:
# (func pid=23140) avg tt dice: 0.26818952
# (func pid=23140) avg tt iou: 0.19378215
# (func pid=23140) avg inf dice: 0.27123788
# (func pid=23140) avg inf iou: 0.19710569
# (func pid=23140) avg inf sensitivity: 0.3757418
# (func pid=23140) avg inf specificity: 0.98778707
# (func pid=23140) avg inf time: 0.2598252296447754
# Training finished iteration 5 at 2025-10-16 21:20:31. Total running time: 6min 3s
# ╭───────────────────────────────╮
# │ Training result               │
# ├───────────────────────────────┤
# │ time_this_iter_s      31.3572 │
# │ time_total_s          357.405 │
# │ training_iteration          5 │
# │ inf_dice             0.271238 │
# │ inf_iou              0.197106 │
# │ inf_time              0.25983 │
# │ tt_dice               0.26819 │
# │ tt_iou               0.193782 │
# │ val_bst_acc           0.46566 │
# ╰───────────────────────────────╯
#
# (func pid=23140)      patientId  tt_diceC  tt_diceAO  tt_diceCA   tt_iouC  tt_iouAO  tt_iouCA  inf_diceC  inf_diceAO  inf_diceCA  inf_iouC  inf_iouAO  inf_iouCA  inf_sensitivityC  inf_sensitivityAO  inf_sensitivityCA  inf_specificityC  inf_specificityAO  inf_specificityCA  inf_time
# (func pid=23140) 0  patient0001  0.642437        0.0        0.0  0.473228       0.0       0.0   0.650101         0.0         0.0  0.481593        0.0        0.0          0.867634                0.0                0.0          0.969605                1.0           0.999999  0.168707
# (func pid=23140) 1  patient0002  0.671746        0.0        NaN  0.505736       0.0       NaN   0.682047         0.0         NaN  0.517505        0.0        NaN          0.856222                0.0                NaN          0.974563                1.0           0.999999  0.276938
# (func pid=23140) 2  patient0003  0.509100        0.0        NaN  0.341472       0.0       NaN   0.511979         0.0         NaN  0.344067        0.0        NaN          0.819806                0.0                NaN          0.945920                1.0           0.999998  0.333830
# Training completed after 5 iterations at 2025-10-16 21:20:31. Total running time: 6min 3s
#
# 2025-10-16 21:20:31,038	WARNING tune.py:1122 -- Trial Runner checkpointing failed: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training', which is outside base dir 'C:\Users\User\ray_results\AICUP_training'
# Trial status: 1 TERMINATED
# Current time: 2025-10-16 21:20:31. Total running time: 6min 3s
# Logical resource usage: 1.0/20 CPUs, 1.0/1 GPUs
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name         status       exp                      iter     total time (s)     tt_dice     tt_iou     val_bst_acc │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ main_0b4c9_00000   TERMINATED   ...'AICUP_training'}        5            357.405     0.26819   0.193782         0.46566 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# (func pid=23140) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23140) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23140) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23140) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23140) Caught sync error: Sync process failed: GetFileInfo() yielded path 'C:/Users/User/ray_results/AICUP_training/main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28', which is outside base dir 'C:\Users\User\ray_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28\'. Retrying after sleeping for 1.0 seconds...
# (func pid=23140) Could not upload checkpoint to d://\Felix\ML\Code\CardiacSegV2\exps\exps\DynUNet\chgh\tune_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
# (func pid=23140) Could not upload checkpoint to d://\Felix\ML\Code\CardiacSegV2\exps\exps\DynUNet\chgh\tune_results\AICUP_training\main_0b4c9_00000_0_exp=exp_AICUP_training_2025-10-16_21-14-28 even after 3 retries.Please check if the credentials expired and that the remote filesystem is supported. For large checkpoints or artifacts, consider increasing `SyncConfig(sync_timeout)` (current value: 1800 seconds).
#
# ================================================================================
#
# ✅ 訓練完成！
# 最佳模型已儲存至: .\models\best_model.pth
# 最終模型已儲存至: .\models\final_model.pth
#
# ================================================================================
#
# ✅ 訓練完成！
# 最佳模型已儲存至: .\models\best_model.pth
# 最終模型已儲存至: .\models\final_model.pth

# %% [markdown]
# # 4. 測試訓練結果
#
# 使用訓練好的模型進行測試評估。

# %%
# 測試模型 (Windows 版本)
import os
import sys
import subprocess

# 確保在正確的目錄
original_dir = os.getcwd()
os.chdir(workspace_dir)

print(f"當前工作目錄: {os.getcwd()}")
print("開始測試...\n")

# 建構測試命令
test_cmd = [
    sys.executable, "expers/tune.py",
    "--tune_mode=test",
    f"--exp_name={exp_name}",
    f"--data_name={data_name}",
    f"--data_dir={data_dir}",
    f"--root_exp_dir={root_exp_dir}",
    f"--model_name={model_name}",
    f"--model_dir={model_dir}",
    f"--log_dir={log_dir}",
    f"--eval_dir={eval_dir}",
    f"--data_dicts_json={data_dicts_json}",
    "--pin_memory",
    "--out_channels=4",
    "--patch_size=4",
    "--feature_size=48",
    "--drop_rate=0.1",
    "--depths", "3", "3", "9", "3",
    "--kernel_size", "7",
    "--exp_rate", "4",
    "--norm_name=layer",
    "--a_min=-42",
    "--a_max=423",
    "--space_x=0.7",
    "--space_y=0.7",
    "--space_z=1.0",
    "--roi_x=128",
    "--roi_y=128",
    "--roi_z=128",
    "--optim=AdamW",
    "--lr=5e-4",
    "--weight_decay=5e-4",
    f"--checkpoint={final_checkpoint}",
    "--use_init_weights",
    "--infer_post_process",
    "--resume_tuner",
    "--save_eval_csv",
    "--test_mode"
]

print("執行命令:")
print(" ".join(test_cmd))
print("\n" + "="*80 + "\n")

# 使用 Popen 來即時顯示輸出
process = subprocess.Popen(
    test_cmd,
    cwd=workspace_dir,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    universal_newlines=True
)

# 即時打印輸出
for line in process.stdout:
    print(line, end='')

# 等待程序完成
return_code = process.wait()

# 切回原始目錄
os.chdir(original_dir)

print("\n" + "="*80)
if return_code == 0:
    print("\n✅ 測試完成！")
else:
    print(f"\n❌ 測試失敗，錯誤碼: {return_code}")
    print("請查看上方的錯誤訊息以了解失敗原因")
